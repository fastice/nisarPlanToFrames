# %% [markdown]
# # Merge Track Frame and Mission Plan for an Arctic Cycle 19
# ---

# %% [markdown]
# This notebook will read all the data from a kmz for a cycle and save the results a gpkg.  It also take this plan an intersect it with the track frame data base so the frame show the actual extent of the data aquisition, including short frames and 80MHz half-width frames.

# %%
import geopandas as gpd
import pandas as pd
import fiona
from matplotlib import pyplot as plt
import shapely
from shapely.geometry import Polygon, MultiPolygon
import numpy as np
fiona.drvsupport.supported_drivers['LIBKML'] = 'rw'
from datetime import datetime
import pytz
from subprocess import call
import os
import warnings

# %% [markdown]
# ## Support Functions

# %%
def computeTrack(myTime):
    '''
    Use time to compute track. Needs fine tuning near equator.
    '''
    secsCycle = 12. * 86400.
    track = ((myTime.timestamp() + 3100 + 25160 ) % secsCycle)/secsCycle * 173
    track = (track - 141) % 173
    frame = (track-int(track))*176
    #print(track, frame)
    return int(track)

def getMode(obsFile, layer, mode, direction, tMin=0, tMax=3600, bbox=(-180, 58, 180,90)):
    '''
    Pull the rows for a layer (in kml file), mode (mode number), direction (ascending/descending).
    Optionally select only those data takes with a duration defined by tMin and tMax. 
    Filter geographically with bbox. 
    '''
    # Layer names contain direction
    if direction in layer and mode in layer:
        # read kml for specfied layer
        gdf = gpd.read_file(obsFile, bbox=bbox, drivers='LIBKML', layer=layer)
        # Only proceed if ther is data
        if gdf.shape[0] <= 0:
            return None
        # Compute data take duration and filter by duration
        gdf['deltaT'] = (gdf['end'] - gdf['begin']).apply(pd.Timedelta.total_seconds)
        tkeep = (gdf['deltaT'] > tMin) & (gdf['deltaT'] <= tMax)
        gdf = gdf[tkeep]
        # Compute the track number
        gdf['track'] = gdf['begin'].apply(computeTrack)
        gdf['mode'] = mode
        # reset indices to reflect order in frame
        gdf.reset_index(drop=True, inplace=True)
        print(f'M{mode} {gdf.shape[0]}', end=' ')
        if gdf.shape[0] > 0: 
            return gdf 
    return None

# %%
def getDataTakes(obsFile, direction, bw, bbox=(-180, -90, 180,-60), saveToFile=True, tMin=0, tMax=3600, fileNameBase='Antarctica'): 
    '''
    Get all the data takes for a cycle (cycle number) with a given direction (ascending/descending).
    if saveToFile, then save to file with fileNameBase_bwMHz.Direction.cycleN.tMin.tMax.gpkg.
    '''
    # All L-band data modes for given BWs
    bwModes = {'80': ['150', '220', '246'],
               '40': ['151', '156', '223', '237', '238', '242', '247'], 
               '20': ['128', '129', '133', '136', '139', '142','143', '148', '149', '152', '155', '158', '159', '163', '166'], 
               '5': ['153', '232', '219', '218', '214' ]}
    modes = bwModes[str(bw)]
    print(obsFile)
    gdfs = []
    with open(obsFile, 'rb') as fp:
        for layer in fiona.listlayers(fp):
            for mode in modes:
                gdf = getMode(obsFile, layer, mode, direction, tMin=tMin, tMax=tMax)
                
                if gdf is not None:
                    gdf.drop('timestamp', inplace=True, axis=1)
                    gdf['bandwidth'] = bw
                    gdfs.append(gdf)
    allData = gpd.GeoDataFrame(pd.concat(gdfs))
    # Get rid of invalid timestamps so the results can be saved
    #allData.drop('timestamp', inplace=True, axis=1)
    # Reset index to reflect current row order
    allData.reset_index(drop=True, inplace=True)
    # save if requested
    if saveToFile:
        shortDirection = {'ascending': 'Asc', 'descending': 'Desc'}[direction]
        allData.to_file(f'Antarctica/{fileNameBase}_{bw}MHz.{shortDirection}.{cycle:03d}.{tMin}.{tMax}.gpkg')
    return allData

# %%
def mergePoly(myGeometry):
    ''' 
    Merge multipilygons. These appear to occur where a frame straddles the -180, 180 transition. 
    Update the <-180 values with +360, to produce continue > 180 values. Then merge the polygons.
    '''
    # Single polygon in the Multipolygon, the return it
    if len(myGeometry.geoms) == 1:
        return list(myGeometry.geoms)[0]
    # Loop through multipolygons and fix coordinates.
    polygons = []
    for poly in myGeometry.geoms:
        x, y = np.array(poly.exterior.xy)
        x[x < 0.] = x[x < 0.] + 360
        newPoly = Polygon(zip(x,y))
        polygons.append(newPoly)
    # merge the result
    merged = shapely.ops.unary_union(MultiPolygon(polygons))
    # If not merged discard
    if merged.geom_type == 'MultiPolygon':
        print(merged)
        return None
    return merged

# %%
def intersectFrameAndSwath(swath, frame):
    ''' 
    Take a swath row from the acquisition plan and a frame row from the track frame data base
    and find the intersection. Return an updated from with the geometry for just the area acquired
    '''
    # intersections are not perfect and lead to biases in the estimated area, these values force full frame coverage to 1
    biases = {80: 0.48256000000000004,
              40: 0.961515,
              5: 0.9600569999999999,
             20: 0.9600569999999999}# There are no 20s and this is just a guess
    
    oldGeometry = frame['geometry']
    newGeometry = swath['geometry'].intersection(oldGeometry)
    if newGeometry.geom_type == 'MultiPolygon':
        newGeometry = mergePoly(newGeometry)
        if newGeometry is None:
            return None
    frame['geometry'] = newGeometry
    areaCoverage = newGeometry.area/oldGeometry.area
  
    areaCoverage /= biases[ swath['bandwidth']]
    frame['coverage'] = areaCoverage
    frame['mode'] = swath['mode']
    return frame

# %% [markdown]
# ## Load KMLs

# %% [markdown]
# There is an offset between track numbers in the TF dB and the ROP KMLs. This function will convert the database version to the kml version. The offset may change as the ROP evolves.

# %%
def trackToSwath(track):
    return (track +97) % 173

# %% [markdown]
# Convert kmz to kml.

# %% [markdown]
# Read KMLs and convert to geopkgs. Seperate into short (<=8s) and long (>8s) data takes.

# %%
cycle = 7
dfs =  {}
# tracks in swath and TF dB offset releative to each others
obsFile = f'ROP358/observationkmzs/Cycle{cycle:03d}_vis.kml'
#
fileNameBase = 'Arctic'
bbox = (-180,58, 180, 90)
with warnings.catch_warnings():
    warnings.simplefilter("ignore")  # suppress deprecation warndings
    for bw in [5, 20, 40, 80]:
        print(bw)
        dfs[f'Asc{bw}All'] = getDataTakes(obsFile, 'ascending', bw, bbox=bbox, 
                                          saveToFile=True, tMin=0, tMax=3600, fileNameBase=fileNameBase);
        dfs[f'Desc{bw}All']  = getDataTakes(obsFile, 'descending', bw, bbox=bbox, 
                                            saveToFile=True, tMin=0, tMax=3600, fileNameBase=fileNameBase);
        dfs[f'Asc{bw}Long'] = getDataTakes(obsFile, 'ascending', bw, bbox=bbox,
                                           saveToFile=True, tMin=8, tMax=3600, fileNameBase=fileNameBase);
        dfs[f'Desc{bw}Long'] = getDataTakes(obsFile, 'descending', bw, bbox=bbox,
                                            saveToFile=True, tMin=8, tMax=3600, fileNameBase=fileNameBase);
        dfs[f'Asc{bw}Short'] = getDataTakes(obsFile, 'ascending', bw, bbox=bbox,
                                            saveToFile=True, tMin=0, tMax=8, fileNameBase=fileNameBase);
        dfs[f'Desc{bw}Short'] = getDataTakes(obsFile, 'descending', bw, bbox=bbox,
                                             saveToFile=True, tMin=0, tMax=8, fileNameBase=fileNameBase);
# Out:
# 5
# ROP358/observationkmzs/Cycle007_vis.kml
# M153 292 ROP358/observationkmzs/Cycle007_vis.kml
# M153 265 ROP358/observationkmzs/Cycle007_vis.kml
# M153 254 ROP358/observationkmzs/Cycle007_vis.kml
# M153 239 ROP358/observationkmzs/Cycle007_vis.kml
# M153 38 ROP358/observationkmzs/Cycle007_vis.kml
# M153 26 20
# ROP358/observationkmzs/Cycle007_vis.kml
# M128 2 M148 109 ROP358/observationkmzs/Cycle007_vis.kml
# M128 1 M148 97 ROP358/observationkmzs/Cycle007_vis.kml
# M128 0 M148 106 ROP358/observationkmzs/Cycle007_vis.kml
# M128 0 M148 92 ROP358/observationkmzs/Cycle007_vis.kml
# M128 2 M148 3 ROP358/observationkmzs/Cycle007_vis.kml
# M128 1 M148 5 40
# ROP358/observationkmzs/Cycle007_vis.kml
# M156 102 M237 1 M238 21 ROP358/observationkmzs/Cycle007_vis.kml
# M156 109 M237 1 M238 8 ROP358/observationkmzs/Cycle007_vis.kml
# M156 98 M237 1 M238 12 ROP358/observationkmzs/Cycle007_vis.kml
# M156 104 M237 1 M238 3 ROP358/observationkmzs/Cycle007_vis.kml
# M156 4 M237 0 M238 9 ROP358/observationkmzs/Cycle007_vis.kml
# M156 5 M237 0 M238 5 80
# ROP358/observationkmzs/Cycle007_vis.kml
# M150 30 M246 24 ROP358/observationkmzs/Cycle007_vis.kml
# M150 45 M246 2 ROP358/observationkmzs/Cycle007_vis.kml
# M150 30 M246 12 ROP358/observationkmzs/Cycle007_vis.kml
# M150 43 M246 0 ROP358/observationkmzs/Cycle007_vis.kml
# M150 0 M246 12 ROP358/observationkmzs/Cycle007_vis.kml
# M150 2 M246 2

# %% [markdown]
# ## Read Track-Frame

# %% [markdown]
# Read track frame data base and fix frames that straddle $\pm$180.

# %%
TF = gpd.read_file('NISAR_TrackFrame_L_20240530.gpkg', bbox=bbox)
TFall = gpd.read_file('NISAR_TrackFrame_L_20240530.gpkg')
TF['geometry'] = TF['geometry'].apply(mergePoly)

# %% [markdown]
# # Intersect Mission Plan with Track Frame

# %% [markdown]
# This step intersects the mission plan with the track frames and saves frame geometry that corresponds to the area actually acquired.
# Note this step conversts data to 3413 to do the intersections and then back to 4326, which avoids problems with crossing the $\pm$180 boundary.

# %%
# %%time
i = 0
fig, axes = plt.subplots(2, 4, figsize=(20, 10))
modeNames = ['Asc80All', 'Desc80All', 'Asc40All', 'Desc40All', 'Desc20All','Asc20All', 'Asc5All', 'Desc5All']
colors = ['r', 'b', 'orange', 'gold', 'magenta', 'dodgerblue', 'gold', 'gray']
modes = dict(zip(modeNames, [{'color': color, 'used': False} for color in colors]))
counts =  dict(zip(modeNames,[0, 0, 0, 0, 0,0, 0, 0]))
countsFraction = dict(zip(modeNames,[0, 0, 0, 0, 0,0, 0, 0]))
axesByMode = dict(zip(modeNames, axes.flatten()))
blackUsed = False
framed = {}
for mode in modes:
    print(mode)
    swaths = dfs[mode]
    #print(len(swaths))
    correctedFrames = []
    for track in range(1, 174):
        # get al TF DB frames for traack
        TFTrack = TF[TF['track'] == track].to_crs(epsg=3413)
        # get all swaths that correspond to that track
        swathsTrack = swaths[swaths['track'] == trackToSwath(track)].to_crs(epsg=3413)
        #print(len(swathsTrack))
        # Loop on swath
        for swath in swathsTrack.iterrows():
            # Get the frames that intersect the swath
            frames = TFTrack[TFTrack.intersects(swath[1]['geometry'])]
            # Intersect swath with frames
            for frame in frames.iterrows():
                correctedFrame = intersectFrameAndSwath(swath[1], frame[1])
                i +=1
                if correctedFrame is not None:
                    correctedFrames.append(correctedFrame)
        #print(len(correctedFrames))
    framedPlan = gpd.GeoDataFrame(pd.concat(correctedFrames, axis=1).transpose(), crs="EPSG:3413").to_crs(epsg=4236)
    framedPlan.reset_index(drop=True, inplace=True)
    framedPlan.to_file(f'Arctic/{mode}.{cycle:03d}.Framed.gpkg')
    framed[mode] = framedPlan
#X = framedPlan.to_crs(epsg=3413)
    for row in framedPlan.to_crs(epsg=3413).iterrows():
        #print(row)
        label = None
        ax = axesByMode[mode]
        counts[mode] += 1
        countsFraction[mode] += row[1]['coverage']
        
        if row[1]['coverage'] < 0.15:
            if not blackUsed: 
                label = 'Short (< 15%)'
                blackUsed = True
            ax.plot(*row[1]['geometry'].exterior.xy, color='k', label=label)
        else:
            if not modes[mode]['used']:
                label = mode
                modes[mode]['used'] = True
            ax.plot(*row[1]['geometry'].exterior.xy, color=modes[mode]['color'], label=label)

for ax in axes.flatten():
    ax.legend()
    ax.set_xlim(-4.e6, 4.e6)
    ax.set_ylim(-4.e6, 4.e6)
    ax.set_aspect('equal')
fig.tight_layout()
# Out:
# Asc80All
# Desc80All
# Asc40All
# Desc40All
# Desc20All
# Asc20All
# Asc5All
# MULTIPOLYGON (((-1150191.2973552034 1189511.8683793072, -1150255.393651746 1189501.261165311, -1160927.8181015458 1254542.6560272842, -1150191.2973552034 1189511.8683793072)), ((-1189098.94970906 1426664.6929107585, -1174867.8309404354 1339497.849076433, -1189168.8802844454 1426653.3217339856, -1189098.94970906 1426664.6929107585)))
# Desc5All
# CPU times: user 12.7 s, sys: 200 ms, total: 12.8 s
# Wall time: 13.5 s

# %%
counts['landIce'] = np.sum([counts[x] for x in ['Asc80All', 'Desc80All']])
pd.DataFrame(counts.items(), columns=['Mode', 'Numnber of Frames'])
# Out:
#         Mode  Numnber of Frames
# 0   Asc80All                187
# 1  Desc80All                181
# 2   Asc40All                352
# 3  Desc40All                353
# 4  Desc20All                459
# 5   Asc20All                456
# 6    Asc5All               1014
# 7   Desc5All                984
# 8    landIce                368

# %%
countsFraction['landIce'] = np.sum([countsFraction[x] for x in ['Asc80All', 'Desc80All']])
pd.DataFrame(countsFraction.items(), columns=['Mode', 'Numnber of Frames'])
# Out:
#         Mode  Numnber of Frames
# 0   Asc80All         133.071574
# 1  Desc80All         128.066071
# 2   Asc40All         242.050500
# 3  Desc40All         244.841327
# 4  Desc20All         379.319564
# 5   Asc20All         361.322108
# 6    Asc5All         717.519975
# 7   Desc5All         719.021963
# 8    landIce         261.137645

# %%
counts.items()
# Out:
# dict_items([('Asc80All', 187), ('Desc80All', 181), ('Asc40All', 352), ('Desc40All', 353), ('Desc20All', 459), ('Asc20All', 456), ('Asc5All', 1014), ('Desc5All', 984), ('landIce', 368)])

# %% [markdown]
# ## Check Coverage Unbiased

# %%
for f in framed:
    c = framed[f]['coverage']
    print(f, np.median(c[c > 0.9]))
    plt.plot(framed[f]['coverage'], 'r.')
# Out:
# Asc80All 1.0004137523438787
# Desc80All 1.0001979254945847
# Asc40All 1.0008024928786576
# Desc40All 1.00093715906766
# Desc20All 1.0024320181180366
# Asc20All 1.0022965707270939
# Asc5All 1.0000769833058414
# Desc5All 0.9999797366438514
